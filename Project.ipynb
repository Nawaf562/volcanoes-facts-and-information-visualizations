# %% [markdown]
# ![ine-divider](https://user-images.githubusercontent.com/7065401/92672068-398e8080-f2ee-11ea-82d6-ad53f7feb5c0.png)
# <hr>
#
# ### Introduction to Data Science with Python — Starter Pass
#
# # Volcanoes facts and information visualizations
#
# In this project, you will be practice how to create visualizations using a dataset from the [Smithsonian Institution's Global Volcanism Program (GVP)](https://volcano.si.edu/) which contains information and features of more than 1,500 volcanoes with eruptions during the Holocene period (approximately the last 10,000 years).
#
# ![volcanoe](https://user-images.githubusercontent.com/7065401/103826161-0e762c80-5055-11eb-9204-27691075c3d7.png)

# %% [markdown]
# ![orange-divider](https://user-images.githubusercontent.com/7065401/92672455-187a5f80-f2ef-11ea-890c-40be9474f7b7.png)
#
# ## Knowing our data
#
# Before starting it's important to load all the libraries we'll be using and understand the data we'll be working on.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('volcanoes.csv')

# %% [markdown]
# Take a look at some records of your data, analyze columns and values:

# %%
df.head(60)
# Out:
#     Number                       Name             Country  \
# 0   210010  West Eifel Volcanic Field             Germany
# 1   210020            Chaine des Puys              France
# 2   210030        Olot Volcanic Field               Spain
# 3   210040   Calatrava Volcanic Field               Spain
# 4   211001                 Larderello               Italy
# 5   211003                    Vulsini               Italy
# 6   211004                Colli Alban               Italy
# 7   211010              Campi Flegrei               Italy
# 8   211020                   Vesuvius               Italy
# 9   211030                     Ischia               Italy
# 10  211031                   Palinuro               Italy
# 11  211040                  Stromboli               Italy
# 12  211041                    Panarea               Italy
# 13  211042                     Lipari               Italy
# 14  211050                    Vulcano               Italy
# 15  211060                       Etna               Italy
# 16  211070  Campi Flegrei Mar Sicilia               Italy
# 17  211071                Pantelleria               Italy
# 18  211080                    Marsili               Italy
# 19  211800                     Amiata               Italy
# 20  212020                    Methana              Greece
# 21  212030                      Milos              Greece
# 22  212040                  Santorini              Greece
# 23  212050                    Nisyros              Greece
# 24  212051                       Yali              Greece
# 25  212805                        Kos              Greece
# 26  213000                       Kula              Turkey
# 27  213001            Karapinar Field              Turkey
# 28  213002                 Hasan Dagi              Turkey
# 29  213003                  Gollu Dag              Turkey
# 30  213004            Acigol-Nevsehir              Turkey
# 31  213010               Erciyes Dagi              Turkey
# 32  213011                 Karaca Dag              Turkey
# 33  213020                Nemrut Dagi              Turkey
# 34  213030              Tenduruk Dagi              Turkey
# 35  213040                     Ararat              Turkey
# 36  214010                     Elbrus              Russia
# 37  214020                     Kazbek             Georgia
# 38  214050    Samsari Volcanic Center             Georgia
# 39  214060                    Aragats             Armenia
# 40  214070               Ghegam Ridge             Armenia
# 41  214080                 Dar-Alages             Armenia
# 42  214090                      Porak  Armenia-Azerbaijan
# 43  214100            Tskhouk-Karckar  Armenia-Azerbaijan
# 44  221010             Tair, Jebel at               Yemen
# 45  221020               Zubair Group               Yemen
# 46  221021                      Zukur               Yemen
# 47  221022                     Hanish               Yemen
# 48  221030                      Jalua             Eritrea
# 49  221040                       Alid             Eritrea
# 50  221041                     Dallol            Ethiopia
# 51  221050                   Gada Ale            Ethiopia
# 52  221060              Alu-Dalafilla            Ethiopia
# 53  221071                   Bora Ale            Ethiopia
# 54  221080                   Erta Ale            Ethiopia
# 55  221090                   Ale Bagu            Ethiopia
# 56  221091                Hayli Gubbi            Ethiopia
# 57  221100                      Dubbi             Eritrea
# 58  221101                      Nabro             Eritrea
# 59  221102                   Mallahle    Ethiopia-Eritrea
#
#                             Region                 Type     Activity Evidence  \
# 0   Mediterranean and Western Asia              Maar(s)        Eruption Dated
# 1   Mediterranean and Western Asia         Lava dome(s)        Eruption Dated
# 2   Mediterranean and Western Asia  Pyroclastic cone(s)     Evidence Credible
# 3   Mediterranean and Western Asia  Pyroclastic cone(s)        Eruption Dated
# 4   Mediterranean and Western Asia  Explosion crater(s)     Eruption Observed
# 5   Mediterranean and Western Asia              Caldera     Eruption Observed
# 6   Mediterranean and Western Asia              Caldera    Evidence Uncertain
# 7   Mediterranean and Western Asia              Caldera     Eruption Observed
# 8   Mediterranean and Western Asia        Stratovolcano     Eruption Observed
# 9   Mediterranean and Western Asia              Complex     Eruption Observed
# 10  Mediterranean and Western Asia            Submarine        Eruption Dated
# 11  Mediterranean and Western Asia        Stratovolcano     Eruption Observed
# 12  Mediterranean and Western Asia        Stratovolcano    Evidence Uncertain
# 13  Mediterranean and Western Asia    Stratovolcano(es)        Eruption Dated
# 14  Mediterranean and Western Asia    Stratovolcano(es)     Eruption Observed
# 15  Mediterranean and Western Asia    Stratovolcano(es)     Eruption Observed
# 16  Mediterranean and Western Asia            Submarine     Eruption Observed
# 17  Mediterranean and Western Asia               Shield     Eruption Observed
# 18  Mediterranean and Western Asia            Submarine        Eruption Dated
# 19  Mediterranean and Western Asia         Lava dome(s)  Unrest / Pleistocene
# 20  Mediterranean and Western Asia         Lava dome(s)     Eruption Observed
# 21  Mediterranean and Western Asia    Stratovolcano(es)        Eruption Dated
# 22  Mediterranean and Western Asia            Shield(s)     Eruption Observed
# 23  Mediterranean and Western Asia        Stratovolcano     Eruption Observed
# 24  Mediterranean and Western Asia         Lava dome(s)     Evidence Credible
# 25  Mediterranean and Western Asia           Caldera(s)  Unrest / Pleistocene
# 26  Mediterranean and Western Asia  Pyroclastic cone(s)     Evidence Credible
# 27  Mediterranean and Western Asia  Pyroclastic cone(s)     Evidence Credible
# 28  Mediterranean and Western Asia        Stratovolcano     Evidence Credible
# 29  Mediterranean and Western Asia            Lava dome    Evidence Uncertain
# 30  Mediterranean and Western Asia              Caldera        Eruption Dated
# 31  Mediterranean and Western Asia        Stratovolcano        Eruption Dated
# 32  Mediterranean and Western Asia               Shield     Evidence Credible
# 33  Mediterranean and Western Asia        Stratovolcano     Eruption Observed
# 34  Mediterranean and Western Asia               Shield     Eruption Observed
# 35  Mediterranean and Western Asia        Stratovolcano     Eruption Observed
# 36  Mediterranean and Western Asia        Stratovolcano        Eruption Dated
# 37  Mediterranean and Western Asia        Stratovolcano        Eruption Dated
# 38  Mediterranean and Western Asia         Lava cone(s)    Evidence Uncertain
# 39  Mediterranean and Western Asia        Stratovolcano     Evidence Credible
# 40  Mediterranean and Western Asia       Volcanic field        Eruption Dated
# 41  Mediterranean and Western Asia    Volcanic field(s)        Eruption Dated
# 42  Mediterranean and Western Asia        Stratovolcano        Eruption Dated
# 43  Mediterranean and Western Asia  Pyroclastic cone(s)        Eruption Dated
# 44              Africa and Red Sea        Stratovolcano     Eruption Observed
# 45              Africa and Red Sea               Shield     Eruption Observed
# 46              Africa and Red Sea               Shield     Evidence Credible
# 47              Africa and Red Sea               Shield     Evidence Credible
# 48              Africa and Red Sea        Stratovolcano     Evidence Credible
# 49              Africa and Red Sea        Stratovolcano     Evidence Credible
# 50              Africa and Red Sea  Explosion crater(s)     Eruption Observed
# 51              Africa and Red Sea        Stratovolcano     Evidence Credible
# 52              Africa and Red Sea      Fissure vent(s)     Eruption Observed
# 53              Africa and Red Sea        Stratovolcano     Evidence Credible
# 54              Africa and Red Sea               Shield     Eruption Observed
# 55              Africa and Red Sea        Stratovolcano     Evidence Credible
# 56              Africa and Red Sea               Shield     Evidence Credible
# 57              Africa and Red Sea        Stratovolcano     Eruption Observed
# 58              Africa and Red Sea        Stratovolcano     Eruption Observed
# 59              Africa and Red Sea        Stratovolcano    Evidence Uncertain
#
#    Last Known Eruption  Latitude  Longitude  Elevation (Meters)  \
# 0             8300 BCE    50.170      6.850                 600
# 1             4040 BCE    45.775      2.970                1464
# 2              Unknown    42.170      2.530                 893
# 3             3600 BCE    38.870     -4.020                1117
# 4              1282 CE    43.250     10.870                 500
# 5              104 BCE    42.600     11.930                 800
# 6              Unknown    41.730     12.700                 949
# 7              1538 CE    40.827     14.139                 458
# 8              1944 CE    40.821     14.426                1281
# 9              1302 CE    40.730     13.897                 789
# 10            8040 BCE    39.480     14.830                 -70
# 11             2016 CE    38.789     15.213                 924
# 12             Unknown    38.638     15.064                 399
# 13             1230 CE    38.490     14.933                 590
# 14             1890 CE    38.404     14.962                 500
# 15             2016 CE    37.734     15.004                3330
# 16             1867 CE    37.100     12.700                  -8
# 17             1891 CE    36.770     12.020                 836
# 18            1050 BCE    39.284     14.399                -779
# 19             Unknown    42.900     11.630                1738
# 20             258 BCE    37.615     23.336                 760
# 21              140 CE    36.699     24.439                 751
# 22             1950 CE    36.404     25.396                 367
# 23             1888 CE    36.586     27.160                 698
# 24             Unknown    36.671     27.140                 180
# 25             Unknown    36.852     27.251                 430
# 26             Unknown    38.580     28.520                 750
# 27             Unknown    37.670     33.650                1302
# 28             Unknown    38.130     34.170                3253
# 29             Unknown    38.250     34.570                2143
# 30            2080 BCE    38.537     34.621                1683
# 31            6880 BCE    38.531     35.447                3864
# 32             Unknown    37.670     39.830                1957
# 33             1650 CE    38.654     42.229                2948
# 34             1855 CE    39.356     43.874                3514
# 35             1840 CE    39.700     44.300                5165
# 36               50 CE    43.351     42.442                5642
# 37             750 BCE    42.700     44.500                5050
# 38             Unknown    41.542     43.700                3290
# 39             Unknown    40.530     44.200                4095
# 40            1900 BCE    40.275     44.750                3597
# 41            2000 BCE    39.704     45.551                1637
# 42             778 BCE    40.028     45.740                3029
# 43            3000 BCE    39.730     46.020                3000
# 44             2008 CE    15.550     41.830                 244
# 45             2013 CE    15.050     42.180                 191
# 46             Unknown    14.020     42.750                 624
# 47             Unknown    13.720     42.730                 422
# 48             Unknown    15.042     39.820                 713
# 49             Unknown    14.880     39.920                 904
# 50             2011 CE    14.242     40.300                 -48
# 51             Unknown    13.975     40.408                 287
# 52             2008 CE    13.793     40.553                 578
# 53             Unknown    13.725     40.600                 668
# 54             2016 CE    13.600     40.670                 613
# 55             Unknown    13.520     40.630                1031
# 56             Unknown    13.500     40.720                 521
# 57             1861 CE    13.579     41.809                1625
# 58             2012 CE    13.370     41.700                2218
# 59             Unknown    13.270     41.650                1875
#
#                           Dominant Rock Type  \
# 0                                    Foidite
# 1                      Basalt / Picro-Basalt
# 2           Trachybasalt / Tephrite Basanite
# 3                      Basalt / Picro-Basalt
# 4                                    No Data
# 5                    Trachyte / Trachydacite
# 6                                    Foidite
# 7                    Trachyte / Trachydacite
# 8         Phono-tephrite /  Tephri-phonolite
# 9                    Trachyte / Trachydacite
# 10                                 Phonolite
# 11  Trachyandesite / Basaltic Trachyandesite
# 12              Andesite / Basaltic Andesite
# 13                                  Rhyolite
# 14          Trachybasalt / Tephrite Basanite
# 15          Trachybasalt / Tephrite Basanite
# 16          Trachybasalt / Tephrite Basanite
# 17                                  Rhyolite
# 18                                       NaN
# 19                                       NaN
# 20              Andesite / Basaltic Andesite
# 21                                  Rhyolite
# 22                                    Dacite
# 23                                    Dacite
# 24                                  Rhyolite
# 25                                       NaN
# 26          Trachybasalt / Tephrite Basanite
# 27  Trachyandesite / Basaltic Trachyandesite
# 28                                    Dacite
# 29                                  Rhyolite
# 30                                  Rhyolite
# 31                                    Dacite
# 32                     Basalt / Picro-Basalt
# 33                                  Rhyolite
# 34                     Basalt / Picro-Basalt
# 35              Andesite / Basaltic Andesite
# 36                                    Dacite
# 37              Andesite / Basaltic Andesite
# 38              Andesite / Basaltic Andesite
# 39              Andesite / Basaltic Andesite
# 40              Andesite / Basaltic Andesite
# 41              Andesite / Basaltic Andesite
# 42              Andesite / Basaltic Andesite
# 43              Andesite / Basaltic Andesite
# 44          Trachybasalt / Tephrite Basanite
# 45                     Basalt / Picro-Basalt
# 46                     Basalt / Picro-Basalt
# 47                     Basalt / Picro-Basalt
# 48                     Basalt / Picro-Basalt
# 49                                  Rhyolite
# 50                                   No Data
# 51                     Basalt / Picro-Basalt
# 52                     Basalt / Picro-Basalt
# 53                     Basalt / Picro-Basalt
# 54                     Basalt / Picro-Basalt
# 55                     Basalt / Picro-Basalt
# 56                     Basalt / Picro-Basalt
# 57                     Basalt / Picro-Basalt
# 58                   Trachyte / Trachydacite
# 59                   Trachyte / Trachydacite
#
#                                 Tectonic Setting
# 0         Rift Zone / Continental Crust (>25 km)
# 1         Rift Zone / Continental Crust (>25 km)
# 2        Intraplate / Continental Crust (>25 km)
# 3        Intraplate / Continental Crust (>25 km)
# 4   Subduction Zone / Continental Crust (>25 km)
# 5   Subduction Zone / Continental Crust (>25 km)
# 6   Subduction Zone / Continental Crust (>25 km)
# 7   Subduction Zone / Continental Crust (>25 km)
# 8   Subduction Zone / Continental Crust (>25 km)
# 9   Subduction Zone / Continental Crust (>25 km)
# 10  Subduction Zone / Continental Crust (>25 km)
# 11  Subduction Zone / Continental Crust (>25 km)
# 12  Subduction Zone / Continental Crust (>25 km)
# 13  Subduction Zone / Continental Crust (>25 km)
# 14  Subduction Zone / Continental Crust (>25 km)
# 15  Subduction Zone / Continental Crust (>25 km)
# 16        Rift Zone / Continental Crust (>25 km)
# 17        Rift Zone / Continental Crust (>25 km)
# 18                                           NaN
# 19  Subduction Zone / Continental Crust (>25 km)
# 20  Subduction Zone / Continental Crust (>25 km)
# 21  Subduction Zone / Continental Crust (>25 km)
# 22  Subduction Zone / Continental Crust (>25 km)
# 23  Subduction Zone / Continental Crust (>25 km)
# 24  Subduction Zone / Continental Crust (>25 km)
# 25  Subduction Zone / Continental Crust (>25 km)
# 26       Intraplate / Continental Crust (>25 km)
# 27       Intraplate / Continental Crust (>25 km)
# 28       Intraplate / Continental Crust (>25 km)
# 29       Intraplate / Continental Crust (>25 km)
# 30       Intraplate / Continental Crust (>25 km)
# 31       Intraplate / Continental Crust (>25 km)
# 32       Intraplate / Continental Crust (>25 km)
# 33       Intraplate / Continental Crust (>25 km)
# 34       Intraplate / Continental Crust (>25 km)
# 35       Intraplate / Continental Crust (>25 km)
# 36       Intraplate / Continental Crust (>25 km)
# 37       Intraplate / Continental Crust (>25 km)
# 38       Intraplate / Continental Crust (>25 km)
# 39       Intraplate / Continental Crust (>25 km)
# 40       Intraplate / Continental Crust (>25 km)
# 41       Intraplate / Continental Crust (>25 km)
# 42       Intraplate / Continental Crust (>25 km)
# 43       Intraplate / Continental Crust (>25 km)
# 44           Rift Zone / Oceanic Crust (< 15 km)
# 45           Rift Zone / Oceanic Crust (< 15 km)
# 46           Rift Zone / Oceanic Crust (< 15 km)
# 47           Rift Zone / Oceanic Crust (< 15 km)
# 48     Rift Zone / Intermediate Crust (15-25 km)
# 49     Rift Zone / Intermediate Crust (15-25 km)
# 50     Rift Zone / Intermediate Crust (15-25 km)
# 51     Rift Zone / Intermediate Crust (15-25 km)
# 52     Rift Zone / Intermediate Crust (15-25 km)
# 53     Rift Zone / Intermediate Crust (15-25 km)
# 54     Rift Zone / Intermediate Crust (15-25 km)
# 55     Rift Zone / Intermediate Crust (15-25 km)
# 56     Rift Zone / Intermediate Crust (15-25 km)
# 57     Rift Zone / Intermediate Crust (15-25 km)
# 58     Rift Zone / Intermediate Crust (15-25 km)
# 59     Rift Zone / Intermediate Crust (15-25 km)

# %%
df.columns
# Out:
# Index(['Number', 'Name', 'Country', 'Region', 'Type', 'Activity Evidence',
#        'Last Known Eruption', 'Latitude', 'Longitude', 'Elevation (Meters)',
#        'Dominant Rock Type', 'Tectonic Setting'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1508 entries, 0 to 1507
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Number               1508 non-null   int64
#  1   Name                 1508 non-null   object
#  2   Country              1508 non-null   object
#  3   Region               1508 non-null   object
#  4   Type                 1508 non-null   object
#  5   Activity Evidence    1507 non-null   object
#  6   Last Known Eruption  1508 non-null   object
#  7   Latitude             1508 non-null   float64
#  8   Longitude            1508 non-null   float64
#  9   Elevation (Meters)   1508 non-null   int64
#  10  Dominant Rock Type   1455 non-null   object
#  11  Tectonic Setting     1501 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 141.5+ KB

# %%
df.shape
# Out:
# (1508, 12)

# %%
df.isna().sum()
# Out:
# Number                  0
# Name                    0
# Country                 0
# Region                  0
# Type                    0
# Activity Evidence       1
# Last Known Eruption     0
# Latitude                0
# Longitude               0
# Elevation (Meters)      0
# Dominant Rock Type     53
# Tectonic Setting        7
# dtype: int64

# %% [markdown]
# ![orange-divider](https://user-images.githubusercontent.com/7065401/92672455-187a5f80-f2ef-11ea-890c-40be9474f7b7.png)
#
# ## Fixing types
#
# We can see different types of volcanoes but some of them contains `(es)`, `(s)` or `?` at the end.
#
# Use the following Regular Expressions to replace that values with empty strings:
#
# - `r'\((.*)\)'`: selects everything between two parentheses;
# - `r'\?'`: selects `?` question mark.

# %%
types = { "Type": {
    r'\((.*)\)': "",
    r'\?': ""
}}

df.replace(types, regex=True, inplace=True)

# %%
df['Type'].value_counts()
# Out:
# Type
# Stratovolcano         722
# Shield                164
# Submarine             118
# Pyroclastic cone      117
# Caldera                97
# Volcanic field         89
# Complex                55
# Lava dome              50
# Maar                   21
# Fissure vent           18
# Compound               14
# Tuff cone              12
# Pyroclastic shield      8
# Crater rows             6
# Subglacial              6
# Lava cone               4
# Unknown                 3
# Explosion crater        2
# Cone                    1
# Tuff ring               1
# Name: count, dtype: int64

# %% [markdown]
# ![orange-divider](https://user-images.githubusercontent.com/7065401/92672455-187a5f80-f2ef-11ea-890c-40be9474f7b7.png)
#
# ## Show the amount of volcanoes per type using a bar plot
#
# > Customize it! You can try different bar colors or different bars orientation, etc.

# %%
bartypes = df['Type'].value_counts()

bartypes.plot(kind='bar',
           color='skyblue',
           title='Amount of volcanoes per type',
           figsize=(12, 6))

plt.show()

# %% [markdown]
# ![orange-divider](https://user-images.githubusercontent.com/7065401/92672455-187a5f80-f2ef-11ea-890c-40be9474f7b7.png)
#
# ## Show the top 10 countries with more volcanoes using a bar plot
#
# > Customize it! You can try different bar colors or different bars orientation, etc.

# %%
topten = df['Country'].value_counts().head(10)
topten.plot(kind='bar',
            color='green',
            title='Top-10 Countries with more volcanoes',
            figsize=(12, 6))
plt.show()

# %% [markdown]
# ![orange-divider](https://user-images.githubusercontent.com/7065401/92672455-187a5f80-f2ef-11ea-890c-40be9474f7b7.png)
#
# ## Show the amount of volcanoes of each tectonic setting using a pie plot

# %%
tectonic_counts = df['Tectonic Setting'].value_counts().head(7)

tectonic_counts.plot(kind='pie',
                 labels=tectonic_df.index,
                 autopct='%1.1f%%',
                 startangle=140,
                 title='Amount of volcanoes per Tectonic setting',
                 figsize=(8,8))
plt.ylabel('')
plt.show()

# %% [markdown]
# ![orange-divider](https://user-images.githubusercontent.com/7065401/92672455-187a5f80-f2ef-11ea-890c-40be9474f7b7.png)
#
# ## Analyze volcanoes elevation using a Box plot

# %%
df['Elevation (Meters)'].plot(kind='box',
                              title='Volcanoes Elevation',
                              figsize=(8, 6))

plt.show()

# %% [markdown]
# ![orange-divider](https://user-images.githubusercontent.com/7065401/92672455-187a5f80-f2ef-11ea-890c-40be9474f7b7.png)
#
# ## Over or under the sea?
#
# Create a new `Under the sea` column which should have `True` if the volcanoe elevation is less than or equal to 0, `False` otherwise.

# %%
df['Under the sea'] = df['Elevation (Meters)'] <= 0
df.head(20)
# Out:
#     Number                       Name  Country  \
# 0   210010  West Eifel Volcanic Field  Germany
# 1   210020            Chaine des Puys   France
# 2   210030        Olot Volcanic Field    Spain
# 3   210040   Calatrava Volcanic Field    Spain
# 4   211001                 Larderello    Italy
# 5   211003                    Vulsini    Italy
# 6   211004                Colli Alban    Italy
# 7   211010              Campi Flegrei    Italy
# 8   211020                   Vesuvius    Italy
# 9   211030                     Ischia    Italy
# 10  211031                   Palinuro    Italy
# 11  211040                  Stromboli    Italy
# 12  211041                    Panarea    Italy
# 13  211042                     Lipari    Italy
# 14  211050                    Vulcano    Italy
# 15  211060                       Etna    Italy
# 16  211070  Campi Flegrei Mar Sicilia    Italy
# 17  211071                Pantelleria    Italy
# 18  211080                    Marsili    Italy
# 19  211800                     Amiata    Italy
#
#                             Region              Type     Activity Evidence  \
# 0   Mediterranean and Western Asia              Maar        Eruption Dated
# 1   Mediterranean and Western Asia         Lava dome        Eruption Dated
# 2   Mediterranean and Western Asia  Pyroclastic cone     Evidence Credible
# 3   Mediterranean and Western Asia  Pyroclastic cone        Eruption Dated
# 4   Mediterranean and Western Asia  Explosion crater     Eruption Observed
# 5   Mediterranean and Western Asia           Caldera     Eruption Observed
# 6   Mediterranean and Western Asia           Caldera    Evidence Uncertain
# 7   Mediterranean and Western Asia           Caldera     Eruption Observed
# 8   Mediterranean and Western Asia     Stratovolcano     Eruption Observed
# 9   Mediterranean and Western Asia           Complex     Eruption Observed
# 10  Mediterranean and Western Asia         Submarine        Eruption Dated
# 11  Mediterranean and Western Asia     Stratovolcano     Eruption Observed
# 12  Mediterranean and Western Asia     Stratovolcano    Evidence Uncertain
# 13  Mediterranean and Western Asia     Stratovolcano        Eruption Dated
# 14  Mediterranean and Western Asia     Stratovolcano     Eruption Observed
# 15  Mediterranean and Western Asia     Stratovolcano     Eruption Observed
# 16  Mediterranean and Western Asia         Submarine     Eruption Observed
# 17  Mediterranean and Western Asia            Shield     Eruption Observed
# 18  Mediterranean and Western Asia         Submarine        Eruption Dated
# 19  Mediterranean and Western Asia         Lava dome  Unrest / Pleistocene
#
#    Last Known Eruption  Latitude  Longitude  Elevation (Meters)  \
# 0             8300 BCE    50.170      6.850                 600
# 1             4040 BCE    45.775      2.970                1464
# 2              Unknown    42.170      2.530                 893
# 3             3600 BCE    38.870     -4.020                1117
# 4              1282 CE    43.250     10.870                 500
# 5              104 BCE    42.600     11.930                 800
# 6              Unknown    41.730     12.700                 949
# 7              1538 CE    40.827     14.139                 458
# 8              1944 CE    40.821     14.426                1281
# 9              1302 CE    40.730     13.897                 789
# 10            8040 BCE    39.480     14.830                 -70
# 11             2016 CE    38.789     15.213                 924
# 12             Unknown    38.638     15.064                 399
# 13             1230 CE    38.490     14.933                 590
# 14             1890 CE    38.404     14.962                 500
# 15             2016 CE    37.734     15.004                3330
# 16             1867 CE    37.100     12.700                  -8
# 17             1891 CE    36.770     12.020                 836
# 18            1050 BCE    39.284     14.399                -779
# 19             Unknown    42.900     11.630                1738
#
#                           Dominant Rock Type  \
# 0                                    Foidite
# 1                      Basalt / Picro-Basalt
# 2           Trachybasalt / Tephrite Basanite
# 3                      Basalt / Picro-Basalt
# 4                                    No Data
# 5                    Trachyte / Trachydacite
# 6                                    Foidite
# 7                    Trachyte / Trachydacite
# 8         Phono-tephrite /  Tephri-phonolite
# 9                    Trachyte / Trachydacite
# 10                                 Phonolite
# 11  Trachyandesite / Basaltic Trachyandesite
# 12              Andesite / Basaltic Andesite
# 13                                  Rhyolite
# 14          Trachybasalt / Tephrite Basanite
# 15          Trachybasalt / Tephrite Basanite
# 16          Trachybasalt / Tephrite Basanite
# 17                                  Rhyolite
# 18                                       NaN
# 19                                       NaN
#
#                                 Tectonic Setting  Under the sea
# 0         Rift Zone / Continental Crust (>25 km)          False
# 1         Rift Zone / Continental Crust (>25 km)          False
# 2        Intraplate / Continental Crust (>25 km)          False
# 3        Intraplate / Continental Crust (>25 km)          False
# 4   Subduction Zone / Continental Crust (>25 km)          False
# 5   Subduction Zone / Continental Crust (>25 km)          False
# 6   Subduction Zone / Continental Crust (>25 km)          False
# 7   Subduction Zone / Continental Crust (>25 km)          False
# 8   Subduction Zone / Continental Crust (>25 km)          False
# 9   Subduction Zone / Continental Crust (>25 km)          False
# 10  Subduction Zone / Continental Crust (>25 km)           True
# 11  Subduction Zone / Continental Crust (>25 km)          False
# 12  Subduction Zone / Continental Crust (>25 km)          False
# 13  Subduction Zone / Continental Crust (>25 km)          False
# 14  Subduction Zone / Continental Crust (>25 km)          False
# 15  Subduction Zone / Continental Crust (>25 km)          False
# 16        Rift Zone / Continental Crust (>25 km)           True
# 17        Rift Zone / Continental Crust (>25 km)          False
# 18                                           NaN           True
# 19  Subduction Zone / Continental Crust (>25 km)          False

# %% [markdown]
# ![orange-divider](https://user-images.githubusercontent.com/7065401/92672455-187a5f80-f2ef-11ea-890c-40be9474f7b7.png)
#
# ## Show the amount of undersea volcanoes per Region using a bar plot

# %%
region_sea_df = df.groupby('Region').sum()['Under the sea'].sort_values()

# another possibility
#df.loc[df['Under the sea'] == True, :].groupby('Region').count()['Name'].sort_values()

region_sea_df.plot(kind='barh',
                   color='dodgerblue',
                   title='Undersea volcanoes per Region',
                   figsize=(8,8))

plt.show()

# %% [markdown]
# ![orange-divider](https://user-images.githubusercontent.com/7065401/92672455-187a5f80-f2ef-11ea-890c-40be9474f7b7.png)
#
# ## Show the distribution of the elevation of the volcanoes using an histogram
#
# > Customize it! You can try different colors, different bins amount, alpha values, adding KDE, etc.

# %%
df['Elevation (Meters)'].plot(kind='hist',
                              rwidth=0.8,
                              color="teal",
                              bins=30,
                              density=True,
                              alpha=0.25,
                              title="Price histogram",
                              figsize=(12, 6))

df['Elevation (Meters)'].plot(kind='kde',
                              color='teal',
                              linewidth=3)

plt.show()

# %% [markdown]
# ![orange-divider](https://user-images.githubusercontent.com/7065401/92672455-187a5f80-f2ef-11ea-890c-40be9474f7b7.png)
#
# ## Which are the highest volcanoes?
#
# Create a bar plot showing the `Elevation (Meters)` per volcanoe `Type`.
#
# > Customize it! You can try different bar colors or different bars orientation, etc.

# %%
df['Elevation (Meters)'].plot(kind='hist',
                              bins=30,
                              rwidth=0.8,
                              color='purple',
                              alpha=0.7,
                              title='Distribution of Volcano Elevations',
                              figsize=(12, 6))

plt.xlabel('Elevation (Meters)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ![orange-divider](https://user-images.githubusercontent.com/7065401/92672455-187a5f80-f2ef-11ea-890c-40be9474f7b7.png)
